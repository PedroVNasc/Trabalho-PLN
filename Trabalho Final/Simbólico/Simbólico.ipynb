# %% [markdown]
# # Solução simbólica

# %% [markdown]
# ## Preparação do dicionário

# %%
import csv
from typing import TypedDict
from tqdm import tqdm

# %%
class WordData(TypedDict):
    raiz: set[str]
    tag: set[str]
    features: set[str]


class Node():
    def __init__(self, head: str, data: dict | None = None, prox: dict[str, 'Node'] | None = None):
        self.head = head
        self.data = data
        self.prox = {} if prox is None else prox


class ReGra():
    def __init__(self):
        self.nodes: dict[str, Node] = {}

    def dive(self, current_node: Node, word: str, depth: int):
        # Palavra não existe ou palavra encontrada
        if depth >= len(word) or word[depth] not in current_node.prox.keys():
            return current_node

        # Continua a recursão
        return self.dive(current_node.prox[word[depth]], word, depth + 1)

    def get_parent(self, word: str) -> Node | None:
        if word[0] not in self.nodes.keys():
            return None

        return self.dive(self.nodes[word[0]], word, 1)

    def __getitem__(self, word: str):
        if word[0] not in self.nodes.keys():
            return None

        node = self.dive(self.nodes[word[0]], word, 1)

        if node.head != word:
            return None

        return node.data

    def __setitem__(self, idx: str, value: WordData):
        # #print()
        # print()
        parent = self.get_parent(idx)

        # Se o conjunto está vazio ou uma letra base não existe
        if parent is None:
            if len(idx) == 1:
                self.nodes[idx] = Node(head=idx, data=value)
                return

            parent = Node(head=idx[0])
            self.nodes[idx[0]] = parent

            for i in range(1, len(idx) - 1):
                parent.prox[idx[i]] = Node(head=idx[:i + 1])
                parent = parent.prox[idx[i]]

            parent.prox[idx[-1]] = Node(head=idx, data=value)
            return

        # Se a palavra existe, atualiza os dados
        if parent.head == idx:
            if parent.data is None:
                parent.data = value

            else:
                parent.data['raiz'] = parent.data['raiz'].union(value['raiz'])
                parent.data['tag'] = parent.data['tag'].union(
                    value['tag'])
                parent.data['features'] = parent.data['features'].union(
                    value['features'])

            return

        # Se a palavra não existe, mas é filha de uma que existe
        # cria o nó dela
        if len(parent.head) + 1 == len(idx):
            parent.prox[idx[-1]] = Node(head=idx, data=value)

        # Se a palavra não existe, e não é filha de uma que existe
        # cria um caminho de nós até ela
        else:
            for i in range(len(parent.head), len(idx) - 1):
                parent.prox[idx[i]] = Node(head=idx[:i + 1])
                parent = parent.prox[idx[i]]

            parent.prox[idx[-1]] = Node(head=idx, data=value)

    def __repr__(self) -> str:
        string = ''
        for node in self.nodes.values():
            string += self.build_tree(node)

        return string

    def build_tree(self, current: Node, depth: int = 0):
        string = f"{'-' * depth} {current.head}{' OK' if current.data is not None else ''}\n"

        for node in current.prox.values():
            string += self.build_tree(node, depth + 1)

        return string

    def get_children(self, current: Node, max_depth: int = 10, depth: int = 0) -> list[str]:
        if depth >= max_depth:
            return []

        children = []

        for node in current.prox.values():
            if node.data is not None:
                children.append(node.head)

            children += self.get_children(node, max_depth=max_depth, depth=depth + 1)

        return children

# %%
dicionary_path = "./portilexicon-ud.tsv"
dictionary = ReGra()

with open(dicionary_path) as dic:
    rd = csv.reader(dic, delimiter='\t', quotechar='"')
    qtd_lines = sum(1 for _ in rd)
    dic.seek(0)    
    print('teste')
    
    progress = tqdm(total=qtd_lines, desc='Carregando dicionário')
    
    for row in rd:
        word = row[0]
        raiz = [row[1]]
        tag = [row[2]]
        features = [x for x in row[3].split('|') if x]

        dictionary[word] = WordData(raiz=set(raiz), tag=set(tag), features=set(features))
        
        progress.update(1)
        
    progress.close()

# %% [markdown]
# ## Parsing da Frase

# %%
def clean_text(text: str):
    return text.lower().replace(',', '').replace(
        '.', '').replace('!', '').replace('?', '').replace(';', '')

# %%
def parsing(phrase: str, dictionary: ReGra):
    phrase = clean_text(phrase)
    
    out = {}
    for word in phrase.split():
        out[word] = dictionary[word]
        
        if out[word] is None:
            out[word] = {'raiz': set(['Unknown']), 'tag': set(['Unknown']), 'features': set(['Unknown'])}
            
    return out

# %% [markdown]
# ## Geração da Árvore Sintática
#
# A árvore sintática é gerada através do LX-Parser. Para obter um chave da API siga as instruções em:
#
# [https://portulanclarin.net/workbench/lx-parser/](https://portulanclarin.net/workbench/lx-parser/)

# %%
import requests

# %%
LXPARSER_WS_API_URL = 'https://portulanclarin.net/workbench/lx-parser/api/'

LXPARSER_WS_API_KEY = ''
with open('.lxparser-key', 'r') as f: LXPARSER_WS_API_KEY = f.read()

# %%
# Função fornecida pelos desenvolvedores do LX-Parser

class WSException(Exception):
    'Webservice Exception'
    def __init__(self, errordata):
        "errordata is a dict returned by the webservice with details about the error"
        super().__init__(self)
        assert isinstance(errordata, dict)
        self.message = errordata["message"]
        # see https://json-rpc.readthedocs.io/en/latest/exceptions.html for more info
        # about JSON-RPC error codes
        if -32099 <= errordata["code"] <= -32000:  # Server Error
            if errordata["data"]["type"] == "WebServiceException":
                self.message += f": {errordata['data']['message']}"
            else:
                self.message += f": {errordata['data']!r}"
    def __str__(self):
        return self.message

# %%
# Função fornecida pelos desenvolvedores do LX-Parser

def parse(text, format):
    '''
    Arguments
        text: a string with a maximum of 2000 characters, Portuguese text, with
             the input to be processed
        format: either 'parentheses', 'table' or 'JSON'

    Returns a string or JSON object with the output according to specification in
       https://portulanclarin.net/workbench/lx-parser/
    
    Raises a WSException if an error occurs.
    '''

    request_data = {
        'method': 'parse',
        'jsonrpc': '2.0',
        'id': 0,
        'params': {
            'text': text,
            'format': format,
            'key': LXPARSER_WS_API_KEY,
        },
    }
    request = requests.post(LXPARSER_WS_API_URL, json=request_data)
    response_data = request.json()
    if "error" in response_data:
        raise WSException(response_data["error"])
    else:
        return response_data["result"]

# %%
frase_teste = "Cacharros quentes quentinhus aqui"

# %%
result_table = parse(frase_teste, format="parentheses")
print(result_table)

# %%
import IPython
import svgling
from nltk import Tree

tree: Tree = []
for sentence in result_table.splitlines(keepends=False):
    tree = Tree.fromstring(sentence)
    IPython.display.display(svgling.draw_tree(tree))

# %% [markdown]
# ### Alinhando o dicionário e o LX-Parser
#
# Como eles utilizam símbolos diferentes, é necessário alinhar as classes antes de prosseguir

# %%
symbol_convertion = {
    'A': ['ADJ'],
    'ART': ['DET', 'PRON'],
    'N': ['NOUN'],
    'QNT': ['PRON'],
    'ADV': ['ADV'],
    'P': ['PRON'],
    'REL': ['CCONJ', 'SCONJ'],
    'V': ['VERB'],
    'PRS': ['PRON'],
}

# %%
predicted = []
for word in tree.pos():
    if word[1] != 'PNT':
        predicted.append([word[0], symbol_convertion[word[1]]])

# %%
parsed = [[x[0], x[1]['tag']] for x in parsing(frase_teste, dictionary).items()]

# %%
def aligning(parsed, predicted):
    if len(parsed) != len(predicted):
        print(f"Lengths don't match: {len(parsed)} != {len(predicted)}")
        return []

    aligned_classes = []

    for i in range(len(parsed)):
        if parsed[i][0] != predicted[i][0].lower():
            print(f"Words don't match: {parsed[i][0]} != {predicted[i][0]}")
            return []

        word = predicted[i][0]
        classes = parsed[i][1].intersection(set(predicted[i][1]))

        if len(classes) == 0:
            if 'Unknown' in parsed[i][1]:
                # Cobre a possibilidade de ser um nome
                if 'NOUN' in predicted[i][1]:
                    classes = set(predicted[i][1])

                else:  # Do contrário, é um erro
                    classes = set(['ERROR', predicted[i][1][0]])

            else:  # Mitiga problemas com a imprecisão do parser
                classes = parsed[i][1]

        aligned_classes.append([word, classes])

    return aligned_classes

# %%
aligned_tree = aligning(parsed, predicted)

# %%
for t in aligned_tree: print(t)

# %% [markdown]
# ## Sugere as mudanças

# %% [markdown]
# ### Correção gramatical

# %%
def levenshtein_distance(word1, word2):
    len1 = len(word1)
    len2 = len(word2)

    matrix_len = max(len1, len2) + 1
    matrix = [[0 for _ in range(matrix_len)] for _ in range(matrix_len)]

    for i in range(matrix_len):
        matrix[i][0] = i
        matrix[0][i] = i

    for i in range(1, matrix_len):
        for j in range(1, matrix_len):
            matrix[i][j] = min(matrix[i - 1][j], matrix[i][j - 1], matrix[i - 1][j - 1])
            
            if i > len1:
                matrix[i][j] += 1
            elif j > len2:
                matrix[i][j] += 1
            elif word1[i - 1] != word2[j - 1]:
                matrix[i][j] += 1

    return matrix[matrix_len - 1][matrix_len - 1]

# %%
def get_corrections(word, tag, dictionary):
    word = clean_text(word)
    p = dictionary.get_parent(word)
    
    print(tag)

    # Procura paralavras com 2 até dois caracteres a mais ou a menos
    if len(p.head) > 2:
        p = dictionary.get_parent(p.head[:-2])

    max_depth = max(len(word) - len(p.head) + 2, 4.0)
    children = dictionary.get_children(p, max_depth=max_depth)

    corrections = []
    for c in children:
        if tag == 'ANY' or tag in dictionary[c]['tag']:
            corrections.append(c)

    corrections.sort(key=lambda x: levenshtein_distance(word, x))
    return corrections[:10]

# %%
possible_corrections = {}

for w in aligned_tree:
    if 'ERROR' in w[1]:
        tag = list(w[1] - {'ERROR'})[0]
        possible_corrections[w[0]] = get_corrections(w[0], tag, dictionary)
        
        if len(possible_corrections[w[0]]) == 0:
            possible_corrections[w[0]] = get_corrections(w[0], 'ANY', dictionary)

# %%
print(possible_corrections)

# %% [markdown]
# ### Recorte das melhores soluções

# %%
def extract_details(details):
    details_dict = {}

    for x in details:
        if x == '_':
            continue

        char, value = x.split('=')
        if char in details_dict:
            details_dict[char].append(value)
        else:
            details_dict[char] = [value]

    return details_dict

def prune_corrections(corrections, tree: Tree):
    details = set()
    for x in tree.leaves():
        d = dictionary[x]

        if d is not None:
            details = details.union(d['features'])

    same_root = {}
    for x in corrections:
        roots = dictionary[x]['raiz']

        for root in roots:
            if root in same_root:
                same_root[root].append(x)
            else:
                same_root[root] = [x]

    characteristics = extract_details(details)
    pruned_corrections = []
    for _, similar_words in same_root.items():            
        if len(similar_words) == 1:
            pruned_corrections.append(similar_words[0])
            continue
        
        score = {}
        best_combination = 0
        for word in similar_words:
            score[word] = 0
            word_details = extract_details(dictionary[word]['features'])
            
            for char, values in word_details.items():
                if values[0] in characteristics[char]:
                    score[word] += 1
                    
            if best_combination < score[word]:
                best_combination = score[word]
        
        for word in similar_words:
            if score[word] == best_combination:
                pruned_corrections.append(word)

    return pruned_corrections

# %%
for word, corrections in possible_corrections.items():
    print(prune_corrections(corrections, tree))

# %% [markdown]
# ## Define uma classe para correção

# %%
from corretor import Corretor

# %%
dicionary_path = "./portilexicon-ud.tsv"

LXPARSER_WS_API_KEY = ''
with open('.lxparser-key', 'r') as f: LXPARSER_WS_API_KEY = f.read()

symbol_convertion = {
    'A': ['ADJ'],
    'ART': ['DET', 'PRON'],
    'N': ['NOUN'],
    'QNT': ['PRON'],
    'ADV': ['ADV'],
    'P': ['PRON'],
    'REL': ['CCONJ', 'SCONJ'],
    'V': ['VERB'],
    'PRS': ['PRON'],
}

# %%
teste_corretor = Corretor(dicionary_path)
teste_corretor.setup_key(LXPARSER_WS_API_KEY)
teste_corretor.setup_symbols(symbol_convertion)
# Out:
# Carregando dicionário: 100%|██████████| 1226339/1226339 [00:32<00:00, 37656.26it/s]

# %%
teste_corretor.corrigir_texto("Cachorros quentes quentinhos da aqui")
# Out:
# {'Cachorros': None,
#  'quentes': None,
#  'quentinhos': None,
#  'de': None,
#  'a': None,
#  'aqui': None}

# %% [markdown]
# ## Avaliação da solução

# %%
import pandas as pd
import random
import string

# %%
df = pd.read_csv('./noticias.brwac.csv').drop(['id', 'title', 'uri'], axis=1)
df
# Out:
#                                                    text
# 0     {'paragraphs': array([array(['FotÃ³grafo retra...
# 1     {'paragraphs': array([array(['Giro UOL traz os...
# 2     {'paragraphs': array([array(['29/03/2010 - 12h...
# 3     {'paragraphs': array([array(['Decisão do caso ...
# 4     {'paragraphs': array([array(['ÚLTIMAS NOTÍCIAS...
# ...                                                 ...
# 2835  {'paragraphs': array([array(['Holografias, "hu...
# 2836  {'paragraphs': array([array(['Cresce nº de mul...
# 2837  {'paragraphs': array([array(['Com uma populaçã...
# 2838  {'paragraphs': array([array(['01/01/2010 - 23h...
# 2839  {'paragraphs': array([array(['08/02/2010 - 18h...
#
# [2840 rows x 1 columns]

# %%
def array(l, *args, **kwargs):
  return l

def prepare_text(df, seed=42):
  random.seed(seed)

  sites_text = [eval(x) for x in df['text'].tolist()]
  texts = [[p for p in paragraphs['paragraphs'] if isinstance(p, list)] for paragraphs in sites_text]
  
  texts = [x for paragraphs in texts for phrases in paragraphs for x in phrases if len(x) > 15]

  texts = random.sample(texts, 150)

  return texts

# %%
texts = prepare_text(df)
texts[0]
# Out:
# '"Na região cervical (pescoço), quer na parte da frente, quer na parte de trás, não consta assinalada nenhuma lesão.'

# %%
def check_validity(words):
    for word in words:
        if any(char.isdigit() for char in word) or len(word) < 4:
            return False
    return True


def corrupt_text(text, number=1, seed=42):
    random.seed(seed)
    
    # Remove pontuação
    words = text.translate(str.maketrans('', '', string.punctuation.replace('-', ''))).split()
    original_words = random.choices(words, k=number)
    
    i = 0
    while not check_validity(original_words):
        if i > 100:
            raise RuntimeError('Não há palavras válidas o suficiente')
        original_words = random.choices(words, k=number)
        i += 1

    corruptions = []
    for word in original_words:
        corrupt_word = list(word)

        corrupt_word[random.randint(
            0, len(corrupt_word) - 1)] = random.choice(string.ascii_letters)
        corruptions.append([word, ''.join(corrupt_word)])

    return corruptions

# %%
corruptions = {}
for text in texts:
    corruptions[text] = corrupt_text(text, number=1)

# %%
from corretor import Corretor

dicionary_path = "./portilexicon-ud.tsv"

LXPARSER_WS_API_KEY = ''
with open('.lxparser-key', 'r') as f: LXPARSER_WS_API_KEY = f.read()

symbol_convertion = {
    'A': ['ADJ'],
    'ART': ['DET', 'PRON'],
    'N': ['NOUN'],
    'QNT': ['PRON'],
    'ADV': ['ADV'],
    'P': ['PRON'],
    'REL': ['CCONJ', 'SCONJ'],
    'V': ['VERB'],
    'PRS': ['PRON'],
}

# %%
teste_corretor = Corretor(dicionary_path, key=LXPARSER_WS_API_KEY, symbols=symbol_convertion)
# Out:
# Carregando dicionário:  25%|██▍       | 304909/1226339 [00:07<00:15, 58500.02it/s]Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x753ab13f0d60>>
# Traceback (most recent call last):
#   File "/home/pedrohenrique/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Carregando dicionário:  64%|██████▎   | 781713/1226339 [00:19<00:05, 79989.59it/s]

# %%
result = []
for text in texts:
    for corruption in corruptions[text]:
        text_corrupt = text.replace(corruption[0], corruption[1], 1)
        text_corrupt = text_corrupt.translate(str.maketrans(
            '', '', string.punctuation.replace('-', '').replace(',', '').replace('.', '')))
        
        result.append(teste_corretor.corrigir_texto(text_corrupt.split('.')[0]))

# %%
print(len(result))
# Out:
# 150

# %%
total = len(result)
points = 0
for text, answer in zip(texts, result):
    print(text)
    print(answer)
    print(corruptions[text])
    
    if corruptions[text][0][1] not in answer.keys() or answer[corruptions[text][0][1]] is None:
        total -= 1
    elif corruptions[text][0][0] in answer[corruptions[text][0][1]]:
        points += 1

    print()
# print(corruptions.values())
# Out:
# "Na região cervical (pescoço), quer na parte da frente, quer na parte de trás, não consta assinalada nenhuma lesão.
# {'em': None, 'a': None, 'região': None, 'cervical': None, 'pescoço': None, 'Vuer': ['vus', 'vulgo', 'vulto', 'vulva', 'vulcão', 'vulgar', 'vulgar'], 'parte': None, 'de': None, 'frente': None, 'quer': None, 'trás': None, 'não': None, 'consta': None, 'assinalada': None, 'nenhuma': None, 'lesão': None}
# [['quer', 'Vuer']]
#
# Polícia apreende adolescente suspeito de esfaquear médico no Rio
# {'Polícia': None, 'apreende': None, 'adolescente': None, 'suspeito': None, 'de': None, 'esfabuear': ['escabela', 'escabelas', 'escabela', 'escabelas', 'esférula', 'espaguete', 'estaqueira', 'estaquia', 'estatueta', 'estatura'], 'médico': None, 'em': None, 'o': None, 'Rio': None}
# [['esfaquear', 'esfabuear']]
#
# Sendo um homem branco de classe média, nunca tinha passado por algo do tipo no Brasil, onde fazia parte de uma minoria privilegiada.
# {'Srndo': ['sendo', 'sondo', 'saldo', 'saldo', 'sanjo', 'saudo', 'saído', 'saído', 'sengo', 'sento', 'siado', 'siado', 'sinto'], 'um': None, 'homem': None, 'branco': None, 'de': None, 'classe': None, 'média': None, 'nunca': None, 'tinha': None, 'passado': None, 'por': None, 'algo': None, 'o': None, 'tipo': None, 'em': None, 'Brasil': None, 'onde': None, 'fazia': None, 'parte': None, 'uma': None, 'minoria': None, 'privilegiada': None}
# [['Sendo', 'Srndo']]
#
# "Depois que ela se separou, nos aproximamos e aconteceu o inesperado: nos apaixonamos, nos casamos e hoje temos 3 lindos filhos", diz ele.
# {'Depois': None, 'ela': None, 'separou': None, 'em': None, 'os': None, 'aproximamos': None, 'aconteceu': None, 'o': None, 'inesperado': None, 'nos': None, 'apaixonamos': None, 'casambs': ['casacas', 'casaca', 'casacos', 'casaco', 'casa', 'casadas', 'casados', 'casada', 'casado', 'casa', 'casacão'], 'hoje': None, 'temos': None, 'lindos': None, 'filhos': None, 'diz': None, 'ele': None}
# [['casamos', 'casambs']]
#
# Não se preocupe se isso pode desclassificá-lo, pois afinal de contas, se o valor solicitado por você é muito maior, certamente na entrevista descobriria que a proposta não lhe é atrativa.
# {'Não': None, 'preocupe': None, 'pode': None, 'pois': None, 'afinal': None, 'de': None, 'contas': None, 'o': None, 'valor': None, 'solicitado': None, 'por': None, 'você': None, 'é': None, 'muito': None, 'mabor': ['maior', 'maior', 'major', 'mago', 'magos', 'maio', 'maios', 'malo', 'malo', 'mano', 'mano', 'mano'], 'certamente': None, 'em': None, 'a': None, 'entrevista': None, 'descobriria': None, 'que': None, 'proposta': None, 'não': None, 'atrativa': None}
# [['maior', 'mabor']]
#
# O levantamento foi feito a partir de informações fornecidas pelos municípios pertencentes à calha do Rio Doce, que levantaram os impactos sofridos pelo desastre e demandaram ações de restauração.
# {'O': None, 'levantamento': None, 'foi': None, 'feito': None, 'a': None, 'partir': None, 'de': None, 'informações': None, 'fornecidas': None, 'por': None, 'os': None, 'municípios': None, 'pertencentes': None, 'calha': None, 'o': None, 'Rio': None, 'Doce': None, 'que': None, 'levabtaram': ['levantaram', 'levantara', 'levantaras', 'levantarem', 'leiautaram', 'leiautara', 'leiautaras', 'leiautarem'], 'impactos': None, 'sofridos': None, 'desastre': None, 'demandaram': None, 'ações': None, 'restauração': None}
# [['levantaram', 'levabtaram']]
#
# CIDH presta queixa contra o Brasil por desaparecimentos durante a ditadura
# {'CIDH': ['cidra', 'cilha', 'cilha', 'cima', 'cimo', 'cine', 'cio', 'cio', 'cipó', 'cita', 'cita', 'city'], 'presta': None, 'queixa': None, 'contra': None, 'o': None, 'Brasil': None, 'por': None, 'desaparebimentos': ['desaparecimento', 'desaparelhamento', 'desaparecida', 'desaparecido', 'desaparecida', 'desaparecido', 'desaparição'], 'durante': None, 'a': None, 'ditadura': None}
# [['desaparecimentos', 'desaparebimentos']]
#
# Para Becker, além do cidadão, o governo e a indústria têm de se comprometer com a mudança de hábitos de consumo.
# {'Para': None, 'Becker': ['bunker', 'backup', 'banner', 'beca', 'becas', 'beco', 'becos', 'beque', 'beques', 'berbere'], 'além': None, 'de': None, 'o': None, 'cidadão': None, 'governo': None, 'a': None, 'indústria': None, 'têm': None, 'compbometer': ['comprometem'], 'com': None, 'mudança': None, 'hábitos': None, 'consumo': None}
# [['comprometer', 'compbometer']]
#
# Mas tudo mudou na vida de Giuliani no dia 11 de setembro.
# {'tudo': None, 'Vudou': ['vulgo', 'vulto', 'vulva', 'vus', 'vulcão', 'vulgar', 'vulgar'], 'em': None, 'a': None, 'vida': None, 'de': None, 'Giuliani': ['giclê', 'gigoga', 'gincana', 'gineta', 'ginjinha', 'gipsita'], 'o': None, 'dia': None, 'setembro': None}
# [['mudou', 'Vudou']]
#
# Esse time de agora perdeu a Copa, mas os jogadores foram muito vitoriosos nos seus clubes e num nível em que há grande reconhecimento aqui e no mundo todo que é Champions League, Uefa, Copa do Rei.
# {'time': None, 'de': None, 'agora': None, 'perdeu': None, 'a': None, 'Copa': None, 'os': None, 'jogadores': None, 'foram': None, 'muito': None, 'vitoriosos': None, 'em': None, 'clubes': None, 'um': None, 'nível': None, 'que': None, 'há': None, 'grande': None, 'reconhecimebto': ['reconhecimento', 'reconhecimentos'], 'aqui': None, 'o': None, 'mundo': None, 'todo': None, 'é': None, 'Champions': ['champignon', 'champignons', 'chamado', 'chamados', 'chamado', 'chamados', 'chamalote', 'chamego', 'chamegos', 'chaminés', 'champanha', 'champanhe'], 'League': ['leal', 'leal', 'leiga', 'leigas', 'leiga', 'leigas', 'lanudo', 'lapões', 'larga', 'larga', 'larga'], 'Uefa': ['ufana', 'ufana', 'ulnal', 'um', 'uma', 'una', 'unas', 'uno', 'una', 'unas', 'uno'], 'Rei': None}
# [['reconhecimento', 'reconhecimebto']]
#
# "A tradicional dialética esquerda-direita deixou de ser a única motivação dos eleitores.
# {'A': None, 'tradicional': None, 'dialética': None, 'deixou': None, 'de': None, 'ser': None, 'a': None, 'única': None, 'motivação': None, 'os': None, 'eleitores': None}
# [['esquerda-direita', 'esquorda-direita']]
#
# "Queremos agradecer a todos os locais que manifestaram interesse em um desses tesouros nacionais", disse Bolden.
# {'Queremos': None, 'agradecer': None, 'a': None, 'todos': None, 'os': None, 'locais': None, 'que': None, 'manifestaram': None, 'interesse': None, 'em': None, 'um': None, 'de': None, 'tesouros': None, 'nacionais': None, 'disse': None, 'Bolden': ['boldo', 'boldos', 'bolões', 'bonde', 'bondes', 'bonde', 'bondes', 'bordel', 'boate', 'boates', 'boate', 'boates', 'bobões', 'bobões', 'bode', 'bode']}
# [['Queremos', 'Queremos']]
#
# Macri tinha destinado 16,666 milhões de pesos argentinos para a sede da Scholas Occurrentes em seu país através de um decreto publicado no dia 30 de maio.
# {'Macri': ['maciça', 'maciça', 'macabra', 'macabra'], 'tinha': None, 'destinado': None, 'de': None, 'pesos': None, 'argentinos': None, 'para': None, 'a': None, 'sede': None, 'Scholas': ['scholar'], 'Occurrentes': ['ocorrentes', 'ocorrente', 'obedecentes', 'observantes', 'ocupantes', 'onipotentes', 'onipresente', 'onipresentes', 'oniscientes', 'onividentes'], 'em': None, 'país': None, 'atravbs': ['atraída', 'atraído', 'atraída', 'atraído', 'atriais', 'atrozes', 'atracada', 'atracado', 'atracada', 'atracado', 'atraente', 'atramada', 'atramado', 'atramada', 'atramado', 'atrapada', 'atrapada'], 'um': None, 'decreto': None, 'publicado': None, 'o': None, 'dia': None, 'maio': None}
# [['através', 'atravbs']]
#
# "Para mim, o importante é proteger o vilarejo, o país e a Europa."
# {'Prra': ['prazo', 'proa', 'proam', 'proa', 'prua', 'prazo', 'prear'], 'mim': None, 'o': None, 'importante': None, 'é': None, 'proteger': None, 'vilarejo': None, 'país': None, 'a': None, 'Europa': ['euro', 'europeu', 'europeia', 'europeia', 'európio', 'eurásia']}
# [['Para', 'Prra']]
#
# "A França tem uma batalha longa pela frente, contra um inimigo que continua a atingir países e sociedades que têm a liberdade como um valor universal", declarou o presidente em pronunciamento na manhã desta sexta-feira.
# {'A': None, 'França': ['franca', 'franca', 'franga', 'frangas', 'frango', 'franja', 'franjas', 'franja', 'franjas', 'franja', 'franjas', 'franja', 'franjas', 'franças'], 'tem': None, 'uma': None, 'batalha': None, 'longa': None, 'por': None, 'a': None, 'frente': None, 'contra': None, 'um': None, 'inimigo': None, 'que': None, 'continua': None, 'atingir': None, 'países': None, 'sociedades': None, 'têm': None, 'liberdade': None, 'cobo': ['cibo', 'coco', 'coco', 'colo', 'colo', 'como', 'como', 'coobo', 'copo', 'copo', 'coro', 'coro', 'coso', 'coto', 'coto', 'cozo'], 'valor': None, 'universal': None, 'declarou': None, 'o': None, 'presidente': None, 'em': None, 'pronunciamento': None, 'manhã': None, 'de': None}
# [['como', 'cobo']]
#
# E tem de ter a capacidade de comunicar um sentimento de urgência, de algo que deve e precisa ser feito imediatamente.
# {'tem': None, 'de': None, 'ter': None, 'a': None, 'capacidade': None, 'comunicar': None, 'um': None, 'sentimento': None, 'urgência': None, 'albo': ['albor', 'alho', 'alto', 'alvo', 'ala', 'alar', 'alas', 'ala', 'alas', 'alce', 'alce', 'alfa', 'alfa', 'alga'], 'que': None, 'deve': None, 'precisa': None, 'ser': None, 'feito': None, 'imediatamente': None}
# [['algo', 'albo']]
#
# Mais de mil pessoas estão desabrigadas e um balanço preliminar informa que 2.600 imóveis foram afetados.
# {'Mais': None, 'de': None, 'pessoas': None, 'estão': None, 'desabrigadas': None, 'um': None, 'balanço': None, 'preliminar': None, 'inforba': ['informam', 'informo', 'inferia', 'inferna', 'infirma', 'informe']}
# [['informa', 'inforba']]
#
# Compra-se torradeira a prestações de R$ 10 ao mês e a perder de vista.
# {'Comrra': ['comera', 'comira', 'comora', 'compra', 'compra', 'coobra', 'camara', 'chofra', 'chorra', 'cimbra', 'coara'], 'torradeira': None, 'a': None, 'prestações': None, 'de': None, 'o': None, 'mês': None, 'perder': None, 'vista': None}
# [['Compra-se', 'Comrra-se']]
#
# Se for a certos lugares de culto cubra a cabeça, em outros tire os sapatos, isso é o que eu disse", explicou.
# {'for': None, 'a': None, 'certos': None, 'lugares': None, 'de': None, 'culto': None, 'cubra': None, 'cabeça': None, 'em': None, 'outros': None, 'tire': None, 'os': None, 'sapatbs': ['sapatas', 'sapata', 'sapatos', 'sapato', 'sapatão', 'sapotis', 'sapa', 'sapa', 'sapador', 'saparia'], 'é': None, 'o': None, 'que': None, 'eu': None, 'disse': None, 'explicou': None}
# [['sapatos', 'sapatbs']]
#
# Quatro carros da corporação e duas ambulâncias foram encaminhados ao local --houve relatos de moradores ilhados nas casas.
# {'carros': None, 'de': None, 'a': None, 'corporação': None, 'ambulâncias': None, 'foram': None, 'encaminhados': None, 'o': None, 'local': None, 'hoube': ['hobby', 'hoste', 'haste', 'hoje', 'hojes', 'homem', 'homo', 'homão', 'honra', 'honra', 'hora'], 'relatos': None, 'moradores': None, 'ilhados': None, 'em': None, 'as': None, 'casas': None}
# [['--houve', '--hoube']]
#
# A antropóloga Ana Lúcia Pastore Scheitzmeyer começou a depor ao meio-dia desta quarta-feira (20), no terceiro dia do júri do ex-seminarista Gil Rugai.
# {'A': None, 'antropóloga': None, 'Ana': ['aba', 'aba', 'aia', 'aia', 'ala', 'ala', 'ama', 'ama', 'ano', 'anu', 'anã', 'ara', 'ara', 'asa', 'asa', 'asa', 'ata', 'ata'], 'Lúcia': ['lúcifer', 'lúdica', 'lúdico', 'lúmen', 'lúpus', 'lúnula', 'lúpulo'], 'Pastore': None, 'Scheitzmeyer': ['scherzo', 'schnauzer', 'schottisch', 'schwabacher', 'scholar', 'schwa', 'scratchman', 'script'], 'começou': None, 'a': None, 'depor': None, 'o': None, 'de': None, 'em': None, 'dia': None, 'júri': None, 'Gil': ['gel', 'gim', 'giz', 'gol', 'gag', 'galo', 'gala', 'galo', 'galã', 'galé', 'gay'], 'Rugai': None}
# [['começou', 'começou']]
#
# "Este estudo é interessante porque até agora era difícil isolar os efeitos específicos da carne vermelha sobre o câncer de mama", disse Alexis Willett, da Breakthrough Breast Cancer.
# {'Erte': ['erre', 'erres', 'erre', 'erres', 'erro', 'era', 'eras', 'era', 'eras', 'erma', 'ermo', 'ermas', 'erma', 'ermo', 'ermas', 'erro', 'erva', 'erva'], 'estudo': None, 'é': None, 'interessante': None, 'até': None, 'agora': None, 'era': None, 'difícil': None, 'isolar': None, 'os': None, 'efeitos': None, 'específicos': None, 'de': None, 'a': None, 'carne': None, 'vermelha': None, 'sobre': None, 'o': None, 'câncer': None, 'mama': None, 'disse': None, 'Alexis': ['alexia', 'alexias', 'alelos', 'alelo', 'alemãs', 'alemã', 'alegre', 'alegre', 'alegre', 'alegro', 'alegro', 'aleia', 'aleive'], 'Willett': ['wildiana', 'wildiano', 'wildianas', 'wildianos', 'wattada', 'wattado', 'wattadas', 'wattados', 'wolfiana', 'wolfiano'], 'Breakthrough': ['bragantino', 'bragantinos', 'braquiúro', 'braquiúros', 'braseiro', 'braseiros', 'bravateiro', 'bravateiros', 'brecumbucu', 'brecumbucus'], 'Breast': ['breaste', 'breais', 'brear', 'breará', 'breasse', 'breada', 'breado'], 'Cancer': ['cancela', 'cancelas', 'cancela', 'cancelo', 'cancelas', 'cancelo', 'cancha', 'canchas', 'cancra', 'cancro', 'cancã', 'cancãs']}
# [['Este', 'Erte']]
#
# Na quinta-feira, o ministro de Assuntos Exteriores da Rússia, Serguei Lavrov, denunciou que a nova minuta de resolução mantinha implicitamente o dispositivo de independência automática do Kosovo, contra o que afirmavam EUA e países europeus.
# {'em': None, 'a': None, 'o': None, 'ministro': None, 'de': None, 'Assuntos': None, 'Exteriores': None, 'Rússia': ['resina', 'resinas', 'resina', 'resinas', 'réstia', 'rasca', 'rascas', 'rasca', 'rascas', 'raspa', 'raspas', 'raspa', 'raspas', 'rasura', 'rasura', 'resma', 'resmas', 'resma', 'resmas'], 'Sorguei': ['sorgo', 'sorgos', 'sorteio', 'sorteio', 'sorções', 'socume', 'socumes', 'soirée', 'soirées', 'solares', 'solidez'], 'Lavrov': ['lavada', 'lavado', 'lavadas', 'lavados', 'lavada', 'lavado', 'lavadas', 'lavados', 'lavosa', 'lavoso', 'lavosas', 'lavrada', 'lavrado', 'lavrada', 'lavrado', 'lavador'], 'denunciou': None, 'nova': None, 'minuta': None, 'resolução': None, 'mantinha': None, 'implicitamente': None, 'dispositivo': None, 'independência': None, 'automática': None, 'Kosovo': ['kaiser', 'kart', 'kbyte', 'kbytes', 'kelper', 'kelvin', 'ki', 'kibutz', 'killer', 'kilt'], 'contra': None, 'que': None, 'afirmavam': None, 'EUA': ['euro', 'euros', 'eunuco'], 'países': None, 'europeus': None}
# [['Serguei', 'Sorguei']]
#
# "Demoramos horas para encontrá-lo", disse Inserra.
# {'horas': None, 'para': None, 'disse': None, 'Inserra': ['inserção', 'inserções', 'inseto', 'insetos', 'insânia', 'insídia', 'insônia', 'insight', 'inspirada', 'inspirada']}
# [['encontrá-lo', 'encobtrá-lo']]
#
# Ela também participou da primeira temporada do "Sítio do Pica Pau Amarelo", na Rede Globo, e do seriado "Os Bandidos da Falange".
# {'Ela': None, 'também': None, 'participou': None, 'de': None, 'a': None, 'temporada': None, 'o': None, 'Sítio': None, 'Pica': None, 'Pau': None, 'Amarelo': None, 'em': None, 'Rede': None, 'Glbbo': ['glabra', 'glabro', 'glacê', 'global', 'global', 'globosa', 'globoso'], 'seriado': None, 'Os': None, 'Bandidos': None, 'Falange': None}
# [['Globo', 'Glbbo']]
#
# Esses reféns perceberam que as condições se tornaram significativamente piores uma vez que eles estiveram sob controle dos "Beatles", já que o trio instituía segurança rigorosa e tortura a prisioneiros.
# {'Erses': ['ermes', 'erres', 'erres', 'erves', 'ecoes', 'egues', 'eives', 'eixes', 'empes', 'eques', 'ergas'], 'reféns': None, 'perceberam': None, 'que': None, 'as': None, 'condições': None, 'tornaram': None, 'significativamente': None, 'piores': None, 'uma': None, 'vez': None, 'eles': None, 'estiveram': None, 'sob': None, 'controle': None, 'de': None, 'os': None, 'Beatles': ['beata', 'beatas', 'beato', 'beatos', 'beata', 'beatas', 'beatice', 'beatices', 'beijões', 'beirões', 'beições', 'beições', 'benções'], 'o': None, 'trio': None, 'instituía': None, 'segurança': None, 'rigorosa': None, 'tortura': None, 'a': None, 'prisioneiros': None}
# [['Esses', 'Erses']]
#
# Reeleito presidente do Senado, Sarney diz que esta administração será a última
# {'Reeleito': None, 'presidente': None, 'de': None, 'o': None, 'Senado': None, 'Sarney': ['sarje', 'sarjem', 'sarjes', 'sarpe', 'sarpem', 'sarpes', 'sarre'], 'diz': None, 'esba': ['esgar', 'esmo', 'esmo', 'esse', 'este', 'esboço', 'esboço', 'escada', 'escala', 'escala', 'escama', 'escama', 'escape', 'escapo', 'escape', 'escapo'], 'administração': None, 'será': None, 'a': None}
# [['esta', 'esba']]
#
# Não há um indício de reforma política no horizonte.
# {'Não': None, 'há': None, 'um': None, 'indício': None, 'de': None, 'reforba': ['reforma', 'reformas', 'reforma', 'reformas', 'reforço', 'reforço', 'referee', 'refolgo', 'refolgo', 'refolho', 'refolho', 'reformada', 'reformado', 'refrega', 'refrega'], 'política': None, 'em': None, 'o': None, 'horizonte': None}
# [['reforma', 'reforba']]
#
# O que não há é um prato brasiliense, nem artesanato ou folclore.
# {'O': None, 'que': None, 'não': None, 'há': None, 'é': None, 'um': None, 'prato': None, 'brasbliense': ['brasiliense', 'brasileense', 'brasilense', 'brasiliana', 'brasiliano'], 'artesanato': None, 'folclore': None}
# [['brasiliense', 'brasbliense']]
#
# O museu agora possui quatro exemplares do tubarão-duende coletados em águas australianas.
# {'O': None, 'museu': None, 'agora': None, 'possui': None, 'exemplares': None, 'de': None, 'o': None, 'coletados': None, 'em': None, 'águas': None, 'australianas': None}
# [['tubarão-duende', 'tubarão-duebde']]
#
# A "ação urgente" pede ação de ativistas em mais de 70 países, com mobiliação para que enviem e-mails, cartas e telefonemas às autoridades baianas.
# {'A': None, 'ação': None, 'urgente': None, 'pede': None, 'de': None, 'atovistas': ['ativistas', 'ativista', 'atomistas', 'atomista', 'ametistas', 'analistas', 'animistas', 'arabistas', 'atavismos', 'ativismos'], 'em': None, 'mais': None, 'países': None, 'com': None, 'mobiliação': ['mobilização', 'mobilizações', 'mobiliário', 'mobiliária', 'mobiliários', 'mobiliárias', 'mobilidade', 'mobilidades'], 'para': None, 'que': None, 'enviem': None, 'cartas': None, 'telefonemas': None, 'a': None, 'as': None, 'autoridades': None, 'baianas': None}
# [['ativistas', 'atovistas']]
#
# Em janeiro de 2008 choveu 86 milímetros, bem abaixo da média histórica de 140.
# {'Em': None, 'janeiro': None, 'de': None, 'choveu': None, 'milímetros': None, 'bem': None, 'abaixb': ['abaixam', 'abaixei', 'abaixo', 'abais'], 'a': None, 'média': None, 'histórica': None}
# [['abaixo', 'abaixb']]
#
# Ou a que fica na sua bolsa ou no seu carro por semanas.
# {'a': None, 'que': None, 'foca': None, 'em': None, 'bolsa': None, 'o': None, 'carro': None, 'por': None, 'semanas': None}
# [['fica', 'foca']]
#
# "Para crianças com menos de três anos, que são mais sensíveis, é recomendável passar também", diz Maria Teresa, professora associada da USP (Universidade de São Paulo).
# {'Para': None, 'crianças': None, 'com': None, 'menos': None, 'de': None, 'anos': None, 'que': None, 'são': None, 'mais': None, 'sensíveis': None, 'é': None, 'recomendável': None, 'passar': None, 'também': None, 'diz': None, 'Mabia': ['magia', 'magias', 'mania', 'mania', 'magiar', 'magma', 'magna', 'magra', 'magra', 'maia', 'maias', 'malga'], 'Teresa': ['termia', 'termias', 'terras', 'teremim', 'tergal', 'terma', 'termas', 'termos', 'termos', 'terno'], 'professora': None, 'associada': None, 'a': None, 'USP': ['uso', 'uso', 'usina', 'usinas', 'ustão', 'ustões', 'usura', 'usuras', 'usura', 'usuras', 'usança'], 'Universidade': None, 'São': None, 'Paulo': ['pacto', 'pagão', 'pairo', 'pairo', 'pairo', 'palco', 'palmo', 'palmo', 'palor', 'palpo', 'palpo', 'pango', 'papão', 'parco']}
# [['Maria', 'Mabia']]
#
# Nascido em 1940 em Chittagong, Muhammad Yunus é o terceiro de uma família de 14 filhos, dos quais cinco morreram nos primeiros anos.
# {'Nrscido': ['nascido', 'nascida', 'nascidos', 'nascidas', 'nascido', 'nascida', 'nascidos', 'nascidas', 'narciso', 'narciso', 'néscia', 'néscias', 'néscio', 'néscios'], 'em': None, 'Chittagong': ['chantagens', 'chantagem', 'charlatona', 'chimango', 'chimangos', 'chita', 'chitas', 'chitada', 'chitadas', 'chitada', 'chitadas', 'chutador'], 'Muhammad': ['mudam', 'mudamos', 'mudaram', 'mugiam', 'mugíamos'], 'Yunus': ['yuppie', 'yuppies'], 'é': None, 'o': None, 'de': None, 'uma': None, 'família': None, 'filhos': None, 'os': None, 'quais': None, 'morreram': None, 'anos': None}
# [['Nascido', 'Nrscido']]
#
# Sobre o jogo entre Corinthians e Cruzeiro, podemos falar Gambá e Raposa irão jogar na arena do jacaré, em Sete Lagoas!
# {'Sobre': None, 'o': None, 'jogo': None, 'entre': None, 'Corinthians': ['corintianas', 'corintianos', 'corintiana', 'corintiano', 'coringa', 'coringas', 'corinho', 'corinhos', 'corinósporo', 'corista'], 'Cruzeiro': None, 'podemos': None, 'falar': None, 'Gambá': None, 'Raposa': None, 'irão': None, 'jobar': ['jogar', 'joga', 'jogam', 'jogará', 'joeira', 'joeira'], 'em': None, 'a': None, 'arena': None, 'de': None, 'jacaré': None, 'Lagoas': None}
# [['jogar', 'jobar']]
#
# Nas demais regiões, o tempo poderá ser nublado a parcialmente nublado, com possibilidade de chuva moderada a forte e queda de granizo em áreas isoladas no Norte.
# {'em': None, 'as': None, 'demais': None, 'regiões': None, 'o': None, 'tempo': None, 'poderá': None, 'ser': None, 'nublado': None, 'a': None, 'parcialmente': None, 'com': None, 'possibilidade': None, 'de': None, 'chuva': None, 'moderada': None, 'fobte': ['fonte', 'fontes', 'forte', 'forte', 'febre', 'fobia', 'foice', 'foice', 'frete', 'frete', 'fuste', 'falta', 'falta', 'falta'], 'queda': None, 'granizo': None, 'áreas': None, 'isoladas': None, 'Norte': None}
# [['forte', 'fobte']]
#
# Da Agência Brasil No Rio de Janeiro
# {'de': None, 'a': None, 'Aoência': ['aoristo', 'aorta'], 'Brasil': None, 'em': None, 'o': None, 'Rio': None, 'Janeiro': None}
# [['Agência', 'Aoência']]
#
# Ele tem os detalhes daquela tragédia pessoal bem vivas na memória, como relembrou ao Pelé.Net no último sábado:
# {'Ele': None, 'tem': None, 'os': None, 'detalhes': None, 'de': None, 'tragédia': None, 'pessoal': None, 'bem': None, 'vivas': None, 'em': None, 'a': None, 'memória': None, 'cobo': ['cabo', 'coco', 'coco', 'colo', 'colo', 'copo', 'copo', 'coro', 'coro', 'coto', 'coto', 'covo', 'coxo', 'cubo', 'cubo', 'caba'], 'relembrou': None, 'o': None, 'Pelé': ['pela', 'pela', 'pele', 'pelo', 'pajé', 'pala', 'peal', 'peca', 'peca', 'pega', 'pega', 'pega', 'peia', 'peia']}
# [['como', 'cobo']]
#
# Oficial de movimentação interna - Porteiro
# {'Oficial': None, 'de': None, 'movimentação': None, 'interba': ['interna', 'interna', 'internas', 'interna', 'internas', 'internada', 'interface', 'interfase', 'interior', 'interior', 'internada', 'internato', 'internet'], 'Porteiro': None}
# [['interna', 'interba']]
#
# A equipe médica que atende a ex-refém já retirou a outra bala que atingiu a menina na virilha, e o projétil foi entregue à polícia para passar por perícia.
# {'A': None, 'equipe': None, 'médica': None, 'que': None, 'atende': None, 'a': None, 'já': None, 'retirou': None, 'outra': None, 'bala': None, 'atingiu': None, 'menina': None, 'em': None, 'virilha': None, 'o': None, 'projétil': None, 'foi': None, 'entregue': None, 'polícia': None, 'para': None, 'passar': None, 'por': None, 'perícia': None}
# [['ex-refém', 'eV-refém']]
#
# Já os sítios históricos podem ser vilas, povoados, igrejas etc.. Normalmente eles apresentam cerâmica de origem inglesa”, disse.
# {'Já': None, 'os': None, 'sítios': None, 'históricos': None, 'podem': None, 'ser': None, 'vilas': None, 'povoados': None, 'igrejas': None, 'etc': ['eterna', 'eterno', 'eterna', 'eterna', 'eterno', 'etária', 'etário', 'etérea', 'etéreo', 'etíope']}
# [['eles', 'elbs']]
#
# A OMS (Organização Mundial de Saúde) fecha a conta: metade da população masculina do planeta terá algum grau da disfunção até os 50 anos.
# {'A': None, 'OMS': ['ombro', 'ombros'], 'Organização': None, 'Mundial': None, 'de': None, 'Saúde': None, 'fecha': None, 'a': None, 'conta': None, 'metade': None, 'população': None, 'masculina': None, 'o': None, 'planeta': None, 'tebá': ['tem', 'teca', 'tece', 'tema', 'tema', 'teme'], 'algum': None, 'grau': None, 'disfunção': None, 'até': None, 'os': None, 'anos': None}
# [['terá', 'tebá']]
#
# Estimativas anteriores se baseavam, principalmente, na evolução dos estilos das cerâmicas encontradas em sítios funerários humanos.
# {'Estimativas': None, 'anteriores': None, 'baseavam': None, 'principalmente': None, 'em': None, 'a': None, 'evolução': None, 'de': None, 'os': None, 'estilos': None, 'as': None, 'cerâbicas': ['cerâmicas', 'cerâmica', 'cerâmicas', 'cerâmica', 'cenobitas', 'cenobita', 'cerneiras', 'cervicais', 'cegueiras', 'cercanias', 'cerebelos', 'cerebrina'], 'encontradas': None, 'sítios': None, 'funerários': None, 'humanos': None}
# [['cerâmicas', 'cerâbicas']]
#
# O PSOL protocolou ainda em 18 de outubro na Mesa do Senado a sexta representação contra o presidente licenciado da Casa.
# {'O': None, 'PSOL': ['pool', 'prol', 'peal', 'peoa', 'peso', 'peso', 'pio', 'pio', 'piola', 'piso', 'piso', 'polo'], 'protocolou': None, 'ainda': None, 'em': None, 'de': None, 'outubro': None, 'a': None, 'Mesa': None, 'o': None, 'Senado': None, 'sebta': ['senta', 'sentam', 'sentas', 'sabia', 'sabia', 'salta', 'sarta', 'sedia', 'senga'], 'representação': None, 'contra': None, 'presidente': None, 'licenciado': None, 'Casa': None}
# [['sexta', 'sebta']]
#
# O valor das tarifas será o mesmo estipulado pela Anac para a Infraero.
# {'O': None, 'valor': None, 'de': None, 'as': None, 'tarifas': None, 'será': None, 'o': None, 'mesmo': None, 'estipulado': None, 'peba': None, 'Anac': ['anais', 'anais', 'anani', 'ananá', 'anato', 'anato', 'anca', 'andu', 'anel', 'angu', 'anho', 'anhá'], 'para': None, 'a': None, 'Infraero': ['infração', 'infrações', 'infrassom', 'infrassons', 'infrator', 'infratora', 'infratoras', 'infratores', 'infraordem']}
# [['pela', 'peba']]
#
# Família de Nice encontra bebê são e salvo graças ao Facebook
# {'Família': None, 'de': None, 'Nice': ['naca', 'naco', 'nave', 'neve', 'neve', 'nicho', 'nina', 'nina', 'nisei', 'nome', 'nove', 'nove', 'nuca'], 'encontra': None, 'bebê': None, 'são': None, 'sabvo': ['salvo', 'salvo', 'sabe', 'sabem', 'sabes', 'sabia', 'sacho', 'sacho', 'sacio', 'sagro'], 'graças': None, 'a': None, 'o': None, 'Facebook': ['faceira', 'faceiras', 'faceira', 'faceiras', 'face', 'faces', 'faceira', 'faceta', 'facetas', 'faceta', 'facetas', 'faceta', 'facetas', 'facheiro', 'facção']}
# [['salvo', 'sabvo']]
#
# Mas, além da mística destas religiões, o filme de Trueba mergulhana luta dos moradores do Candeal, que, com Carlinhos Brown, realizamuma obra social e cultural transformada no melhor antídoto contra apobreza e a violência característica das favelas brasileiras.
# {'além': None, 'de': None, 'a': None, 'mística': None, 'religiões': None, 'o': None, 'filme': None, 'Trueba': ['tromba', 'tromba', 'truaca', 'trunfa', 'trunfa', 'tabeca', 'tabela', 'tabela', 'taioba', 'tapema', 'tapena', 'tapera', 'tarefa'], 'mergulhana': ['mergulha', 'mergulhais', 'mergulham', 'mergulhada', 'mergulhadas', 'mergulhado'], 'luta': None, 'os': None, 'moradores': None, 'Candeal': ['candeia', 'candeias', 'candeia', 'candeio', 'candeias', 'candeio', 'candela', 'candelas', 'candiru', 'candor', 'candura', 'candango'], 'que': None, 'com': None, 'Carlinhos': ['carlingas', 'carlinga'], 'Brown': ['broa', 'broas', 'broca', 'brocas', 'broca', 'brocas', 'broma', 'bromo', 'bromo', 'broto', 'broto', 'broxa', 'broxa', 'brocha', 'brocha', 'broche', 'broche'], 'realizamuma': ['realizam', 'realizamos', 'realiza', 'realizada', 'realizadas', 'realizado', 'realizados'], 'obra': None, 'social': None, 'cultbral': ['cultora', 'cultoras', 'cultor', 'cultores', 'cultura', 'culturas', 'culatra', 'culatras', 'culatra', 'culatras', 'cultual', 'cuieira'], 'transformada': None, 'em': None, 'melhor': None, 'antídoto': None, 'contra': None, 'apobreza': ['afoiteza', 'afoitezas', 'aspereza', 'abobra', 'abobras', 'abobreira', 'alfobre', 'alfobres', 'altiveza', 'ambreta'], 'violência': None, 'característica': None, 'as': None, 'favelas': None, 'brasileiras': None}
# [['cultural', 'cultbral']]
#
# Ele ainda tem que cumprir uma carga horária do ano letivo de 2015, paralisado por causa das ocupações.
# {'Ele': None, 'ainda': None, 'tem': None, 'comprir': ['compra', 'compras', 'compra', 'compras', 'compraz'], 'uma': None, 'carga': None, 'horária': None, 'de': None, 'o': None, 'ano': None, 'letivo': None, 'paralisado': None, 'por': None, 'causa': None, 'as': None, 'ocupações': None}
# [['cumprir', 'comprir']]
#
# A Secretaria de Estado de Saúde do Rio informou já ter elaborado um plano de contingência para tratar casos de contaminação pelo vírus ebola .
# {'A': None, 'Secretaria': None, 'de': None, 'Estado': None, 'Saúde': None, 'o': None, 'Rio': None, 'informou': None, 'já': None, 'ter': None, 'elaborado': None, 'um': None, 'plano': None, 'contingêncib': ['contingência', 'contingências'], 'para': None, 'tratar': None, 'casos': None, 'contaminação': None, 'por': None, 'vírus': None, 'ebola': ['ecada', 'ecada', 'edule', 'efusa', 'egeia', 'ereta', 'evolada', 'evolado', 'evolada', 'evolado', 'evolta', 'evolto', 'exata', 'exata']}
# [['contingência', 'contingêncib']]
#
# Azevedo também afirmou que a presidente tem pouco espaço de manobra para reagir aos protestos e que uma possível recuperação da popularidade do governo depende, em grande parte, de a economia voltar a crescer, do controle da inflação e da manutenção da renda e do emprego, além da oferta de bens públicos, como educação e saúde.
# {'Azevedo': ['azares', 'azarado', 'azarada', 'azarados', 'azedador', 'azedadora', 'azeda', 'azeda', 'azulejo', 'azulejo', 'azares', 'azeda'], 'também': None, 'afirmou': None, 'a': None, 'presidente': None, 'tem': None, 'pouco': None, 'espaço': None, 'de': None, 'manobra': None, 'para': None, 'reagir': None, 'os': None, 'protestos': None, 'que': None, 'uma': None, 'possível': None, 'recuperação': None, 'popularidade': None, 'o': None, 'governo': None, 'depende': None, 'em': None, 'grande': None, 'parte': None, 'economia': None, 'voltar': None, 'crescer': None, 'contbole': ['controle', 'controles', 'controle', 'controles', 'cocorote', 'codinome', 'coentro', 'coentros', 'conato', 'conatos', 'conchal', 'concho', 'concho'], 'inflação': None, 'manutenção': None, 'renda': None, 'emprego': None, 'além': None, 'oferta': None, 'bens': None, 'públicos': None, 'educação': None, 'saúde': None}
# [['controle', 'contbole']]
#
# A presidente Dilma Rousseff entra agora no seu 8º mês de mandato.
# {'A': None, 'presidente': None, 'Dilma': ['delta', 'derma', 'diaba', 'dieta', 'dilema', 'dinda', 'dogma', 'drama', 'dália', 'dólmã'], 'Roosseff': ['raros', 'retroses', 'ribose', 'rodos', 'rogos', 'rojos', 'rolos', 'rosas', 'rosas', 'rosbife'], 'entra': None, 'agora': None, 'em': None, 'o': None, 'mês': None, 'de': None, 'mandato': None}
# [['Rousseff', 'Roosseff']]
#
# Em anos e anos foi o único investimento em segurança pública mais concreto que o Rio de Janeiro viu.
# {'Em': None, 'anos': None, 'foi': None, 'o': None, 'único': None, 'investimento': None, 'em': None, 'segurança': None, 'pública': None, 'mais': None, 'concbeto': ['concreto', 'concreta', 'concretas', 'concreto', 'concreta', 'concretas', 'concepto', 'concepta', 'conceptos', 'concreta', 'completo', 'completo', 'conchado', 'conchado', 'congesto'], 'Rio': None, 'de': None, 'Janeiro': None, 'viu': None}
# [['concreto', 'concbeto']]
#
# Elas bebem 200 litros de água por dia.
# {'Elas': None, 'bebem': None, 'litros': None, 'de': None, 'ágba': ['água', 'águas', 'água', 'águas', 'ágio', 'ágios', 'ágape', 'ágapes', 'ágata', 'ágatas', 'ágora', 'águia'], 'por': None, 'dia': None}
# [['água', 'ágba']]
#
# "Talvez, mas o que importa", respondeu a freira.
# {'Talvez': None, 'o': None, 'que': None, 'importa': None, 'respbndeu': ['responde', 'respondes', 'reacendeu', 'rescinde', 'rescindes'], 'a': None, 'freira': None}
# [['respondeu', 'respbndeu']]
#
# "Ligeirinho o Daniel voltou a sorrir", conta o ex-goleiro.
# {'Ligeirinho': None, 'o': None, 'Daniel': ['dança', 'danças', 'dance', 'daime', 'dano', 'dano', 'dança', 'danças', 'dativa', 'dativo', 'dações'], 'voltou': None, 'a': None, 'sorrib': ['sorriso', 'sorgo', 'sorna', 'sornas', 'sorna', 'sornas', 'soro', 'soro', 'sorte'], 'conta': None}
# [['sorrir', 'sorrib']]
#
# A reportagem tentou fazer contato com a família novamente, mas não conseguiu.
# {'A': None, 'reportagem': None, 'tentou': None, 'fazer': None, 'contato': None, 'com': None, 'a': None, 'famílba': ['família', 'familiar', 'familiar', 'fama'], 'novamente': None, 'não': None, 'conseguiu': None}
# [['família', 'famílba']]
#
# Em seu primeiro mandato na Câmara, o deputado Marx Beltrão (PMDB-AL) vive a expectativa de ser anunciado pelo presidente interino, Michel Temer, como novo ministro do Turismo.
# {'Em': None, 'mandato': None, 'em': None, 'a': None, 'Câmara': None, 'o': None, 'deputado': None, 'Marx': ['mar', 'maré', 'maca', 'maga', 'mago', 'maia', 'maio', 'mais', 'maiô', 'mal'], 'Beltrão': ['belisco', 'belisco', 'beltrana', 'beltrano', 'bela', 'bela', 'belas', 'beldade', 'beleza', 'belga', 'belga'], 'vive': None, 'expectativa': None, 'de': None, 'ser': None, 'anunciado': None, 'pebo': ['peco', 'peco', 'pejo', 'pejo', 'pelo', 'pelo', 'pero', 'peso', 'peso', 'peão', 'paco', 'pago', 'pago', 'paio', 'pano', 'pano'], 'presidente': None, 'interino': None, 'Michel': ['micela', 'milhal', 'macela', 'macheza', 'macho', 'machão', 'maciez', 'mainel', 'mantel'], 'Temer': None, 'novo': None, 'ministro': None, 'Turismo': None}
# [['pelo', 'pebo']]
#
# "Se não achasse que tinha condições de ser titular, não estava nem aqui.
# {'não': None, 'achasse': None, 'tinha': None, 'condições': None, 'de': None, 'ser': None, 'titulbr': ['titular', 'titulam', 'titulara', 'titulará', 'titilar', 'titubar'], 'estava': None, 'nem': None, 'aqui': None}
# [['titular', 'titulbr']]
#
# Pedi que meus jogadores corressem pelos funcionários que estavam ali", afirmou o treinador, que viu naquela noite sua equipe buscar um empate emocionante e triunfar nos pênaltis.
# {'Prdi': ['praia', 'praias', 'preá', 'proa', 'proa', 'prol', 'próis', 'pró', 'prós', 'prado', 'praga'], 'que': None, 'jogadores': None, 'corressem': None, 'por': None, 'os': None, 'funcionários': None, 'estavam': None, 'ali': None, 'afirmou': None, 'o': None, 'treinador': None, 'viu': None, 'em': None, 'noite': None, 'equipe': None, 'buscar': None, 'um': None, 'empate': None, 'emocionante': None, 'triunfar': None, 'pênaltis': None}
# [['Pedi', 'Prdi']]
#
# Leila concorreu ao cargo pelo PRB, mas não conseguiu se eleger.
# {'Lrila': ['laica', 'leiga', 'leiga', 'leira', 'leira', 'leiva', 'loira', 'loira', 'léria', 'ladra', 'ladra', 'ladra', 'lagoa', 'laia'], 'concorreu': None, 'a': None, 'o': None, 'cargo': None, 'por': None, 'PRB': ['pró', 'preá', 'proa', 'proa', 'prol', 'prado', 'praga', 'praia', 'prata', 'prato'], 'não': None, 'conseguiu': None, 'eleger': None}
# [['Leila', 'Lrila']]
#
# Qual o número de dias por semana que gera este vínculo?
# {'Qral': ['quara', 'quaram', 'quer', 'quer', 'quadra', 'quadra', 'quadro'], 'o': None, 'número': None, 'de': None, 'dias': None, 'por': None, 'semana': None, 'que': None, 'gera': None, 'vínculo': None}
# [['Qual', 'Qral']]
#
# Se considerarmos a expectativa de vida, chamado IDHM Longevidade, a Ride-DF tem o melhor índice com 0, 857.
# {'considerarmos': None, 'a': None, 'expectativa': None, 'de': None, 'vida': None, 'chamado': None, 'IDHM': ['ida', 'idas', 'ida', 'idas', 'idos', 'ida', 'idas', 'idos', 'idos', 'idade', 'idades', 'ideal', 'ideal', 'ideia', 'ideia', 'idosa', 'idoso', 'idéia'], 'Longevidade': None, 'tem': None, 'o': None, 'melhoR': None, 'índice': None, 'com': None}
# [['melhor', 'melhoR']]
#
# Os desabrigados estão ocupando escolas públicas e casas de parentes na região.
# {'Os': None, 'desabrigados': None, 'estão': None, 'ocupando': None, 'escolas': None, 'públicas': None, 'cabas': None, 'de': None, 'parentes': None, 'em': None, 'a': None, 'região': None}
# [['casas', 'cabas']]
#
# Eu sempre fui um camaleão, qualquer coisa que me pedissem para fazer eu ia fazer.
# {'Eu': None, 'sempre': None, 'fui': None, 'um': None, 'camaleão': None, 'qualquer': None, 'coisa': None, 'que': None, 'pedibsem': ['pedias', 'pedinte', 'pedintei', 'pecassem', 'pedinte'], 'para': None, 'fazer': None, 'eu': None, 'ia': None}
# [['pedissem', 'pedibsem']]
#
# Dispositivo redutor de velocidade de tráfego - Lombada
# {'Dispositivo': None, 'redutor': None, 'de': None, 'velocidade': None, 'tráfebo': ['tráfego', 'tráfico', 'trágico', 'trágica'], 'Lombada': None}
# [['tráfego', 'tráfebo']]
#
# A coisa muda de figura se uma pessoa tiver doenças como sarna, escabiose (piolho), chato (piolho pubiano), oxiúros, micoses, machucados e escaras (feridas que se formam quando pessoa fica muito tempo na cama).
# {'A': None, 'coisa': None, 'muda': None, 'de': None, 'figura': None, 'uma': None, 'pessoa': None, 'tiver': None, 'doenças': None, 'sarna': None, 'escabiose': None, 'piolho': None, 'chato': None, 'pubiano': None, 'oxiúros': None, 'micoses': None, 'machucados': None, 'escarbs': ['escamas', 'escama', 'escamas', 'escama', 'escapas', 'escapas', 'escuras', 'escuras', 'escalar', 'escamosa', 'escamoso', 'escampa', 'escampa', 'escampa'], 'feridas': None, 'que': None, 'formam': None, 'fica': None, 'muito': None, 'tempo': None, 'em': None, 'a': None, 'cama': None}
# [['escaras', 'escarbs']]
#
# "É uma homenagem que não se restringe só a ele, como também a todos que participaram daquela gestão vitoriosa", disse o atual presidente David Fischel, ao descerrar a placa em homenagem a Schwartz, falecida no dia 23 de dezembro de 2003.
# {'É': None, 'uma': None, 'homenagem': None, 'que': None, 'não': None, 'restringe': None, 'só': None, 'a': None, 'ele': None, 'também': None, 'todos': None, 'participaram': None, 'de': None, 'gestão': None, 'vitoriosa': None, 'disse': None, 'o': None, 'atual': None, 'presidente': None, 'David': ['devi', 'devi', 'devida', 'devida', 'dívida', 'dúvida', 'dacha', 'dada', 'dado', 'dada', 'dado'], 'Fischel': ['ficelle', 'fincões', 'fiscal', 'fiscal', 'fisco', 'fiscos', 'fissões', 'fiasco', 'fiascos', 'fiações'], 'descbrrar': ['descarga', 'descargas', 'descarga', 'descargas', 'desforra', 'desforras', 'desforra', 'desforras', 'despertar', 'decorador', 'decorrer', 'desabrigo', 'desabrigo', 'desacerto', 'desacerto', 'desacordo', 'desacordo'], 'placa': None, 'em': None, 'Schwartz': ['schwa', 'scholar', 'scherzo', 'schnauzer', 'schnauzers', 'schottisch'], 'falecida': None, 'dia': None, 'dezembro': None}
# [['descerrar', 'descbrrar']]
#
# "É chegada a hora de parar de fazer o jogo do empurra, em que um empurra para o outro.
# {'É': None, 'chegada': None, 'a': None, 'hora': None, 'de': None, 'porar': ['pomar', 'porra', 'poda', 'podas', 'poda', 'podas', 'poder', 'poma', 'popa', 'poracá'], 'fazer': None, 'o': None, 'jogo': None, 'empurra': None, 'em': None, 'que': None, 'um': None, 'para': None, 'outro': None}
# [['parar', 'porar']]
#
# Foro privilegiado
# {'Foro': None, 'privilegiadb': ['privilegiada', 'privilegiado', 'privilegiadas', 'privilegiados', 'privilegiáveis', 'privilegiada', 'privilegiado', 'privilegiadas', 'privilegiados', 'privilegiada', 'privilegiável', 'privilegiáveis']}
# [['privilegiado', 'privilegiadb']]
#
# Atualizado às 21h25
# {'Aturlizado': ['atualidades', 'atualização', 'atleticano', 'atoalhados', 'atoalhados', 'atomização', 'atrevidaço', 'atrocidade', 'atrofiador'], 'a': None, 'as': None}
# [['Atualizado', 'Aturlizado']]
#
# Um montanhista compartilhou na rede social Reddit uma foto de um gatinho que ele jura que o ajudou a se encontrar depois dele se perder nos Alpes suíços.
# {'Um': None, 'montanhista': None, 'compartilhou': None, 'em': None, 'a': None, 'rede': None, 'social': None, 'Reddit': ['redita', 'redito', 'redita', 'redito', 'reedita', 'reedite', 'reedito', 'redais', 'redata', 'redate', 'redato'], 'uma': None, 'foto': None, 'de': None, 'um': None, 'gatinho': None, 'que': None, 'ele': None, 'jura': None, 'o': None, 'ajudob': ['ajuda', 'ajudas', 'ajuda', 'ajudas', 'ajudada', 'ajudado', 'ajudadas', 'ajudados', 'ajunta', 'ajunta', 'ajuri', 'ajuris', 'ajuste', 'ajuste'], 'encontrar': None, 'depois': None, 'perder': None, 'os': None, 'Alpes': ['alpaca', 'alpacas', 'alpense', 'alpista', 'alpiste', 'alporca', 'alporca'], 'suíços': None}
# [['ajudou', 'ajudob']]
#
# Os autores da proposta aprovada, os deputados Antonio Carlos Biscaia (PT-RJ) e Sérgio Barradas Carneiro (PT-BA), defendem a desburocratização do fim do casamento.
# {'Os': None, 'autores': None, 'de': None, 'a': None, 'proposta': None, 'aprovada': None, 'os': None, 'deputados': None, 'Antonio': ['antolho', 'antolho', 'antofilo', 'antofilos', 'antociano', 'antonímia', 'antologia', 'antologia', 'antotaxia'], 'Carlos': ['cargos', 'carpos', 'carros', 'cachos', 'cactos', 'cairos', 'caldos', 'calos', 'calose', 'calvos'], 'Biscaia': ['bisca', 'biscas', 'bisca', 'biscas', 'biscate', 'biscates', 'biscuit', 'biscoito', 'biscoito'], 'Sérgio': ['sérvio', 'sérvia', 'sérvios', 'sério', 'sérios', 'sargo', 'sargos', 'sereia', 'sereno', 'sereno', 'sermão'], 'Barradas': None, 'Carnbiro': ['carneiro', 'carneiros', 'carneira', 'carreiro', 'carteiro', 'cabreiro', 'cafeeiro', 'caixeiro', 'cajueiro', 'caldeiro', 'caldeiro'], 'defendem': None, 'desburocratização': None, 'o': None, 'fim': None, 'casamento': None}
# [['Carneiro', 'Carnbiro']]
#
# O Internacional, derrotado com um gol de Victorino, aos 34min do primeiro tempo, formou com Gasperin; Toninho, Mauro Pastor, Mauro Galvão e Cláudio Mineiro (Beretta); Batista, Falcão e Jair; Chico Spina, Adilson e Mário Sérgio.
# {'O': None, 'Internacional': None, 'derrotado': None, 'com': None, 'um': None, 'gol': None, 'de': None, 'Victorino': ['vicentino', 'vicentinos', 'vistoria', 'vistorias', 'vistoria', 'vistorias', 'vicilino', 'vicilinos', 'viperino', 'viperinos', 'vistor'], 'a': None, 'os': None, 'o': None, 'tempo': None, 'formou': None, 'Gasperin': ['gasolina', 'gasolinas', 'gastrite', 'gastura', 'gasturas', 'gascão', 'gascões', 'gases', 'gasoduto', 'gasosa'], 'Toninho': ['toninha', 'toninhas', 'tonica', 'tonificou'], 'Mauro': ['macro', 'macros', 'magro', 'magros', 'macho', 'madre', 'magno', 'magra', 'malho', 'malho', 'mambo'], 'Pastor': None, 'Galvão': ['galeão', 'galpão', 'galego', 'galeto', 'galão', 'gansão', 'gascão', 'gavião', 'gabão', 'gaiato', 'gaiato'], 'Cláudbo': ['clinato', 'clorato', 'cloreto', 'clorito', 'clou', 'cláusula', 'clérigo', 'clínico', 'clítico', 'cladódio'], 'Mineiro': None, 'Beretta': ['beberete', 'bendita', 'bendita', 'bereba', 'berebas', 'bererê', 'bererês', 'bermuda', 'bernesa', 'berruga', 'bezerra'], 'Batista': None, 'Falcão': None, 'Jair': ['jabá', 'jaca', 'jaci', 'jacu', 'jacá', 'jade', 'jaez', 'japa', 'japu', 'jarra'], 'Chico': ['chibo', 'chibo', 'chicle', 'chicote', 'chicote', 'china', 'china', 'chio', 'chio', 'chip', 'chips'], 'Spina': ['spin', 'spins', 'spa', 'spas', 'spot', 'spray', 'spread', 'speech', 'sparing', 'speaker'], 'Adilson': ['adiposo', 'adição', 'adulto', 'adultos', 'adelfia', 'adelo', 'adelos', 'ademão', 'ademãos', 'adendo'], 'Mário': ['marco', 'marco', 'marno', 'março', 'mirim', 'mirto', 'morim', 'mormo', 'morno', 'morno', 'morro', 'morro', 'morto', 'morto'], 'Sérgio': ['sérvio', 'sérvios', 'sério', 'sérios', 'sargo', 'sargos', 'sereia', 'sereno', 'sereno', 'sermão']}
# [['Cláudio', 'Cláudbo']]
#
# E, no terceiro ato, os banqueiros demonstraram a sua gratidão voltando-se contra as pessoas que os salvaram, ao apoiar – e disponibilizar a riqueza que eles ainda possuíam graças aos pacotes de socorro – políticos que prometeram manter os impostos em níveis baixos e desmantelar as regulações modestas que foram implementadas após a crise.
# {'em': None, 'o': None, 'ato': None, 'os': None, 'banqueiros': None, 'demonstraram': None, 'a': None, 'gratidão': None, 'voltando': None, 'contra': None, 'as': None, 'pessoas': None, 'que': None, 'salvaram': None, 'apoiar': None, 'disponibilizar': None, 'riqueza': None, 'eles': None, 'ainda': None, 'possuíam': None, 'graças': None, 'pacotes': None, 'de': None, 'socorro': None, 'políbicos': ['polemicas', 'polemico', 'polemicou', 'politicas', 'politico', 'politicou', 'políramos', 'polarizas', 'polarizes', 'polarizo'], 'prometeram': None, 'manter': None, 'impostos': None, 'níveis': None, 'baixos': None, 'desmantelar': None, 'regulações': None, 'modestas': None, 'foram': None, 'implementadas': None, 'após': None, 'crise': None}
# [['políticos', 'políbicos']]
#
# Assim que a foto ia ser tirada, um pato muito rebelde virou as costas para a câmera
# {'Assim': None, 'a': None, 'foto': None, 'ia': None, 'ser': None, 'tirada': None, 'um': None, 'pato': None, 'muito': None, 'rebelbe': ['rebelde', 'rebelde', 'rebeldes', 'rebelada', 'rebelado', 'rebelada', 'rebelado', 'rebolo', 'rebolo', 'rebolo', 'rebolão', 'rebolões', 'rebada', 'rebadas', 'rebada', 'rebadas'], 'virou': None, 'as': None, 'costas': None, 'para': None, 'câmera': None}
# [['rebelde', 'rebelbe']]
#
# Imaginar que o PT pudesse ter esse mesmo tamanho é uma ilusão de qualquer pessoa.
# {'Imarinar': ['imagens', 'imaginador', 'imaginação', 'imaginária', 'imaginário', 'imburana', 'imperial', 'imperial', 'imprensa', 'imprensa', 'ima', 'imaculada', 'imaculada'], 'que': None, 'o': None, 'PT': ['ptose', 'ptério'], 'pudesse': None, 'ter': None, 'mesmo': None, 'tamanho': None, 'é': None, 'uma': None, 'ilusão': None, 'de': None, 'qualquer': None, 'pessoa': None}
# [['Imaginar', 'Imarinar']]
#
# O que as manifestações em Curitiba mostraram é que mesmo que tal afirmativa proceda, o sistema de transporte continua muito aquém das expectativas dos manifestantes.
# {'O': None, 'que': None, 'as': None, 'manifestações': None, 'em': None, 'Curitiba': ['curitibana', 'curitibano'], 'mostraram': None, 'é': None, 'mesmo': None, 'afirmativa': None, 'proceda': None, 'o': None, 'sisteba': ['sistema', 'sistemas', 'sisa', 'sisas', 'sisa', 'sisais', 'sisas', 'siso', 'sisais', 'sismo', 'sismos', 'siso'], 'de': None, 'transporte': None, 'continua': None, 'muito': None, 'aquém': None, 'expectativas': None, 'os': None, 'manifestantes': None}
# [['sistema', 'sisteba']]
#
# 6 dos 8 e-commerces mais acessados do Brasil são clientes UOLDIVEO
# {'de': None, 'os': None, 'mais': None, 'acessados': None, 'o': None, 'Brasib': ['brasil', 'brasa', 'brasas', 'brasido', 'brasão', 'bravio', 'brado', 'brado'], 'são': None, 'clientes': None, 'UOLDIVEO': ['ugolino', 'ugolinos', 'ulmáceo', 'ulmáceos', 'ultimado', 'ultimado', 'ululável', 'umbriano', 'undífero']}
# [['Brasil', 'Brasib']]
#
# Veja qual o plano mais vantajoso em seu estado
# {'Veja': None, 'qual': None, 'o': None, 'plano': None, 'mais': None, 'vantbjoso': ['vantajoso', 'vantajosa', 'varioloso', 'vastados', 'vastados', 'vacantes', 'vaceanos', 'vadeados', 'vadeados', 'vadeosos'], 'em': None, 'estado': None}
# [['vantajoso', 'vantbjoso']]
#
# Seja grato pela cama, pelo teto, pelo momento de descansar.
# {'Seja': None, 'grato': None, 'por': None, 'a': None, 'cama': None, 'pebo': ['peco', 'peco', 'pejo', 'pejo', 'pelo', 'pelo', 'pero', 'peso', 'peso', 'peão', 'paco', 'pago', 'pago', 'paio', 'pano', 'pano'], 'teto': None, 'o': None, 'momento': None, 'de': None, 'descansar': None}
# [['pelo', 'pebo']]
#
# A maioria dos sites de emprego pedem para informar pretensão salarial.
# {'A': None, 'maioria': None, 'de': None, 'os': None, 'sites': None, 'emprego': None, 'pedem': None, 'paba': ['paca', 'pacas', 'paga', 'paga', 'paga', 'paia', 'pala', 'papa', 'papa', 'pata', 'puba', 'puba', 'pacau', 'paco'], 'informar': None, 'pretensão': None, 'salarial': None}
# [['para', 'paba']]
#
# Em seguida, vêm as regiões Norte e Nordeste – na primeira, 68% dos homens e 74,2% das mulheres gastam até 30 minutos para ir ao trabalho, e, na segunda, esse percentual é de 68,6% para os homens e de 72,4% para as mulheres.
# {'Em': None, 'srguida': ['seguida', 'seguida', 'seguida', 'seguida', 'segunda', 'segunda', 'segunda', 'sagrada', 'sagrada', 'sagrada', 'sagui', 'saguis', 'saguiru', 'seguidor'], 'vêm': None, 'as': None, 'regiões': None, 'Norte': None, 'Nordeste': None, 'em': None, 'a': None, 'de': None, 'os': None, 'homens': None, 'mulheres': None, 'gastam': None, 'até': None, 'minutos': None, 'para': None, 'ir': None, 'o': None, 'trabalho': None, 'percentual': None, 'é': None}
# [['seguida', 'srguida']]
#
# ...
# [['autorização', 'autobização']]
#
# Inclui pesquisadores de mais de 300 instituições, incluindo gente da Universidade Federal de São Paulo (Unifesp) e da Faculdade de Medicina da Universidade de São Paulo (USP).
# {'Irclui': ['ira', 'iras', 'iraúna', 'irerê', 'irerês', 'irite', 'irites', 'irmã', 'irmão', 'irmãos'], 'pesquisadores': None, 'de': None, 'mais': None, 'instituições': None, 'incluindo': None, 'gente': None, 'a': None, 'Universidade': None, 'Federal': None, 'São': None, 'Paulo': ['pacto', 'pagão', 'pairo', 'pairo', 'pairo', 'palco', 'palmo', 'palmo', 'palor', 'palpo', 'palpo', 'pango', 'papão', 'parco'], 'Unifesp': ['uniões', 'unhões', 'unções', 'ungidas', 'ungidos', 'ungidas', 'ungidos', 'ungüis', 'unidade', 'uniforme', 'uniforme', 'uniforme', 'universa', 'universo'], 'Faculdade': None, 'Medicina': None, 'USP': ['uso', 'usos', 'uso', 'usina', 'usinas', 'ustão', 'ustões', 'usura', 'usura', 'usança']}
# [['Inclui', 'Irclui']]
#
# Fernando Henrique tinha muita pouca referência de gestão também, e o Lula acho que nenhuma, menos ainda que Marina, que Marina foi por quase oito anos, sete anos, ministra do Meio Ambiente, além de senadora e tudo isso.
# {'Fernando': [], 'Henrique': ['henriquina', 'henriquino'], 'tinha': None, 'muita': None, 'pouca': None, 'referência': None, 'de': None, 'gestão': None, 'também': None, 'o': None, 'Lula': None, 'acho': None, 'que': None, 'nenhuma': None, 'menos': None, 'ainda': None, 'Marina': None, 'foi': None, 'por': None, 'quase': None, 'oibo': ['oito', 'oiti', 'oitis', 'oitão', 'oitões', 'oitava', 'oitavo', 'oitava', 'oitavo', 'oitibó', 'oitiva'], 'anos': None, 'ministra': None, 'Meio': None, 'Ambiente': None, 'além': None, 'senadora': None, 'tudo': None}
# [['oito', 'oibo']]
#
# Em seu primeiro discurso após a cassação do mandato, a petista também voltou a mencionar os votos recebidos na eleição de 2014.
# {'Em': None, 'discurso': None, 'após': None, 'a': None, 'cassação': None, 'de': None, 'o': None, 'mandato': None, 'petista': None, 'também': None, 'voltou': None, 'mencbonar': ['mencionam', 'mencionada', 'mencionado'], 'os': None, 'votos': None, 'recebidos': None, 'em': None, 'eleição': None}
# [['mencionar', 'mencbonar']]
#
# Da RedaçãoEm São Paulo
# {'de': None, 'a': None, 'ReoaçãoEm': ['redação', 'relação', 'ralação', 'rarefação', 'reação', 'rebaçã', 'recapagem', 'redução', 'reedição'], 'São': None, 'Paulo': ['pacto', 'pagão', 'pairo', 'pairo', 'pairo', 'palco', 'palmo', 'palmo', 'palor', 'palpo', 'palpo', 'pango', 'papão', 'parco']}
# [['RedaçãoEm', 'ReoaçãoEm']]
#
# A explosão também feriu dez trabalhadores, dos quais dois estão em estado crítico.
# {'A': None, 'explosão': None, 'também': None, 'feriu': None, 'trabalhadores': None, 'de': None, 'os': None, 'quais': None, 'dobs': ['doas', 'does', 'doas', 'doba', 'dobo', 'dais', 'deba', 'debo'], 'estão': None, 'em': None, 'estado': None, 'crítico': None}
# [['dois', 'dobs']]
#
# Teixeira explicou que as pessoas estão retirando os objetos pessoais aos poucos.
# {'Teireira': ['terreira', 'terreiras', 'terreiro', 'taipeira', 'taipeiras', 'taipeiro', 'telheira', 'terceira', 'toureira', 'tabueira'], 'explicou': None, 'as': None, 'pessoas': None, 'estão': None, 'retirando': None, 'os': None, 'objetos': None, 'pessoais': None, 'a': None, 'poucos': None}
# [['Teixeira', 'Teireira']]
#
# Em longo prazo, as doenças crônicas induzidas pela água resultam em dias perdidos de escola, o que por sua vez faz os estudantes ficarem atrasados em sua educação e seu desenvolvimento intelectual.
# {'Em': None, 'longo': None, 'prazo': None, 'as': None, 'doenças': None, 'crônicas': None, 'induzidas': None, 'por': None, 'a': None, 'áoua': ['água', 'águas', 'água', 'águas', 'área', 'áreas', 'ária', 'árias', 'ágio', 'ágora', 'águia', 'ápoda'], 'resultam': None, 'em': None, 'dias': None, 'perdidos': None, 'de': None, 'escola': None, 'o': None, 'que': None, 'vez': None, 'faz': None, 'os': None, 'estudantes': None, 'ficarem': None, 'atrasados': None, 'educação': None, 'desenvolvimento': None, 'intelectual': None}
# [['água', 'áoua']]
#
# Questionado sobre a foto que tirou ao lado do presidente da Câmara, sob um cartaz que dizia "Um Brasil livre da corrupção", Kataguiri afirmou:
# {'Quertionado': ['questionador', 'questionadora', 'queratina', 'queridona', 'quartinha', 'quentinha', 'quentinha'], 'sobre': None, 'a': None, 'foto': None, 'que': None, 'tirou': None, 'o': None, 'lado': None, 'de': None, 'presidente': None, 'Câmara': None, 'sob': None, 'um': None, 'cartaz': None, 'dizia': None, 'Um': None, 'Brasil': None, 'livre': None, 'corrupção': None, 'Kataguiri': ['kabuqui', 'karaokê', 'kafkiana', 'kafkiano', 'kaiser', 'kamikaze', 'kantiana'], 'afirmou': None}
# [['Questionado', 'Quertionado']]
#
# De acordo com Sampaio, como as pessoas têm direito de se reunir livremente, "não cabe ao poder público dizer onde vai ocorrer uma manifestação".
# {'De': None, 'acordo': None, 'com': None, 'Sampaio': ['sampais', 'sampa', 'sampam', 'sampamos', 'sampar', 'sampado', 'sampada', 'sampados'], 'as': None, 'possoas': ['postes', 'postais', 'postas', 'posta', 'postas', 'posta', 'postas', 'posta', 'posse', 'posses', 'posse', 'posses', 'possessa', 'possesso', 'posters', 'postes'], 'têm': None, 'direito': None, 'de': None, 'reunir': None, 'livremente': None, 'não': None, 'cabe': None, 'a': None, 'o': None, 'poder': None, 'público': None, 'dizer': None, 'onde': None, 'vai': None, 'ocorrer': None, 'uma': None, 'manifestação': None}
# [['pessoas', 'possoas']]
#
# Objetos que sobreviveram ao fim do Império Romano estão em exposição nos Estados Unidos
# {'Objetos': None, 'que': None, 'sobreviveram': None, 'a': None, 'o': None, 'fim': None, 'de': None, 'Império': None, 'Romano': None, 'esbão': ['esbroa', 'esbroo', 'escoo', 'esfio', 'esmoo', 'espio', 'espoo', 'espuo', 'estio', 'estio'], 'em': None, 'exposição': None, 'os': None, 'Estados': None, 'Unidos': None}
# [['estão', 'esbão']]
#
# Nas eleições de 2006, foi duplamente derrotado.
# {'em': None, 'as': None, 'eloições': ['eleições', 'eleição', 'elações', 'elisões', 'elocuções', 'elevações', 'elipses', 'elipses', 'elixires', 'elatinas', 'eleita', 'eleita'], 'de': None, 'foi': None, 'duplamente': None, 'derrotado': None}
# [['eleições', 'eloições']]
#
# O compositor Alfredo Borba fez até uma marchinha para celebrar a equipe.
# {'O': None, 'compositor': None, 'Alfredo': [], 'Borba': ['bomba', 'borda', 'borda', 'borla', 'borra', 'borra', 'bouba', 'boba', 'bobas', 'boba', 'boba', 'bobas', 'bocha', 'boina', 'bolbo'], 'fez': None, 'até': None, 'uma': None, 'marcbinha': ['marchinha', 'manchinha', 'marquinha', 'marquinho', 'manguinha', 'maravilha', 'maravilha', 'maridinho'], 'para': None, 'celebrar': None, 'a': None, 'equipe': None}
# [['marchinha', 'marcbinha']]
#
# Os outros que fizeram estádio privado foram para o Grêmio, não fez isso, o Paraná...
# {'Os': None, 'outros': None, 'que': None, 'fizeram': None, 'estádio': None, 'privado': None, 'foram': None, 'para': None, 'o': None, 'Grêmib': ['grêmio', 'grêmios'], 'não': None, 'fez': None, 'Paraná': ['parada', 'paradas', 'parada', 'paradas', 'parada', 'paradas', 'parati', 'paratis', 'parra', 'parras', 'parra', 'parras', 'paragem', 'paranoia', 'paraíso', 'parca', 'parca']}
# [['Grêmio', 'Grêmib']]
#
# Ele trilhou seu caminho, vinha na beira do abismo, escorregou e caiu", lamentou.
# {'Ele': None, 'trilhou': None, 'caminho': None, 'vinha': None, 'em': None, 'a': None, 'beira': None, 'de': None, 'o': None, 'abismb': ['abismo', 'abismo', 'abis', 'abisga', 'abisso', 'abio', 'abiose'], 'escorregou': None, 'caiu': None, 'lamentou': None}
# [['abismo', 'abismb']]
#
# Os presidentes ressaltaram "sua determinação de desenvolver um espaço sul-americano integrado no político, social, econômico, ambiental e de infra-estrutura, que fortaleça a identidade própria e lhe outorgue uma maior gravitação e representação nos foros internacionais".
# {'Os': None, 'presidentes': None, 'ressaltaram': None, 'determinação': None, 'de': None, 'desenvolver': None, 'um': None, 'espaço': None, 'integrado': None, 'em': None, 'o': None, 'político': None, 'social': None, 'econômico': None, 'ambiental': None, 'que': None, 'fortaleça': None, 'a': None, 'idenbidade': ['identidade', 'identidades', 'idealidade', 'idealidades', 'idoneidade', 'idoneidades', 'identicidade', 'idealizador', 'idealismo', 'idealismos'], 'própria': None, 'outorgue': None, 'uma': None, 'maior': None, 'gravitação': None, 'representação': None, 'os': None, 'foros': None, 'internacionais': None}
# [['identidade', 'idenbidade']]
#
# Outra vizinha, Rachel Reed, 25, o viu algumas vezes na fachada do edifício, com sua mochila.
# {'Outra': None, 'vizinha': None, 'Rachel': ['racha', 'rachas', 'racha', 'rachas', 'rachão', 'rachões', 'racle', 'racles', 'racemo', 'racemos', 'racimo', 'rachador'], 'Reed': ['redes', 'redes', 'real', 'real', 'rebu', 'redil', 'redis', 'redor', 'rega', 'rega', 'rego', 'rei'], 'o': None, 'viu': None, 'algumas': None, 'vezes': None, 'em': None, 'a': None, 'fachaba': ['fachada', 'fachadas', 'facha', 'fachas', 'facada', 'facadas', 'faceira', 'faceira', 'faceira', 'facho', 'fachos', 'factura'], 'de': None, 'edifício': None, 'com': None, 'mochila': None}
# [['fachada', 'fachaba']]
#
# "O que por um lado torna a matriz energética brasileira mais limpa que a média mundial, por outro a torna vulnerável se o clima mudar", afirma Roberto Schaeffer, da UFRJ, coordenador do capítulo de energia.
# {'O': None, 'que': None, 'por': None, 'um': None, 'lado': None, 'torna': None, 'a': None, 'matriz': None, 'energética': None, 'brosileira': ['brasileira', 'brasileira', 'brasileira', 'braceleira', 'bravateira', 'braçadeira', 'britadeira', 'braseira'], 'mais': None, 'limpa': None, 'média': None, 'mundial': None, 'outro': None, 'vulnerável': None, 'o': None, 'clima': None, 'mudar': None, 'afirma': None, 'Roberto': ['rebento', 'rebento', 'rabecão', 'rebordo', 'rebordo', 'rejeito', 'rejeito', 'relento', 'retorto', 'reverso', 'ribeiro', 'ribeiro', 'roceiro'], 'Schaeffer': ['sachardes', 'sachasse', 'sachasses', 'sachaste', 'sarrafear', 'sobrevier', 'subtender'], 'de': None, 'UFRJ': ['ufo', 'ufania'], 'coordenador': None, 'capítulo': None, 'energia': None}
# [['brasileira', 'brosileira']]
#
# Há um evidente conflito de interesses na praça.
# {'Há': None, 'um': None, 'evidente': None, 'conflito': None, 'de': None, 'intebesses': ['interesse', 'interesse', 'interfases', 'indecentes', 'indecisões', 'insucessos', 'intelectos', 'interações', 'interessada', 'interessado'], 'em': None, 'a': None, 'praça': None}
# [['interesses', 'intebesses']]
#
# Vilfredo Schürmann, o líder do grupo, ouviu a história da embarcação primeiramente em 2002.
# {'Vilfredo': ['vilarejo', 'vizirado', 'valerato', 'valores', 'valores', 'varredor', 'vidreiro', 'vigores', 'vigores', 'vilanaço', 'vinhedo'], 'Schürmann': ['siberiana', 'siberiano', 'siluriana', 'siluriano', 'suburbana', 'suburbano', 'sumeriana', 'sumeriano', 'saboreada', 'saboreado', 'saboreada', 'saboreado'], 'o': None, 'líder': None, 'de': None, 'grupo': None, 'ouviu': None, 'a': None, 'histbria': ['histeria', 'história', 'histrião', 'histérica', 'histérico', 'histórica', 'histórico', 'hidrovia'], 'embarcação': None, 'primeiramente': None, 'em': None}
# [['história', 'histbria']]
#
# Segundo Zeitzer, a técnica funciona porque os flashes de luz atravessam a retina e chegam ao fundo do olho, atingindo células que se comunicam com a parte do cérebro que comanda o relógio biológico.
# {'Srgundo': ['segundo', 'segunda', 'segundas', 'segundo', 'segunda', 'segundas', 'segunda', 'sagrado', 'sagrada', 'sagrado', 'sagrada', 'segredo', 'segredo', 'seguida', 'seguida', 'seguida', 'seguida', 'seguidor', 'safanão', 'sagrada'], 'Zeitzer': ['zelador', 'zelote', 'zelotes', 'zelável', 'zenital', 'zebrais', 'zebrada', 'zebrado', 'zebrais', 'zebrina'], 'a': None, 'técnica': None, 'funciona': None, 'os': None, 'flashes': None, 'de': None, 'luz': None, 'atravessam': None, 'retina': None, 'chegam': None, 'o': None, 'fundo': None, 'olho': None, 'atingindo': None, 'células': None, 'que': None, 'comunicam': None, 'com': None, 'parte': None, 'cérebro': None, 'comanda': None, 'relógio': None, 'biológico': None}
# [['Segundo', 'Srgundo']]
#
# Quando colocamos a baleia numa área mais profunda do mar ela ficou fazendo movimentos da esquerda para a direita e acabou voltando para a praia.
# {'colocamos': None, 'a': None, 'baleia': None, 'em': None, 'uma': None, 'área': None, 'mais': None, 'profunda': None, 'de': None, 'o': None, 'mar': None, 'ela': None, 'ficou': None, 'fazendo': None, 'movimentos': None, 'esqubrda': ['esquerda', 'esquerdas', 'esquerda', 'esquerdas', 'esquerda', 'esquerdas', 'escumada', 'escumada', 'esfumada', 'esfumada', 'esquadra', 'esquadra', 'estufada', 'estufada', 'escabela', 'escabela', 'escalada', 'escalada', 'escalada', 'escapada', 'escapada', 'escapada', 'escudela', 'escudela'], 'para': None, 'direita': None, 'acabou': None, 'voltando': None, 'praia': None}
# [['esquerda', 'esqubrda']]
#
# Primeiro, os médicos, as enfermeiras e os trabalhadores sociais ou os religiosos perguntam aos pacientes:
# {'Prireiro': ['paireis', 'paqueiro', 'paqueiro', 'parireis', 'piririco', 'pombeiro', 'predirão', 'prefiro', 'preiteio'], 'os': None, 'médicos': None, 'as': None, 'enfermeiras': None, 'trabalhadores': None, 'sociais': None, 'religiosos': None, 'perguntam': None, 'a': None, 'pacientes': None}
# [['Primeiro', 'Prireiro']]
#
# "A primeira-ministra explicou que é preciso um tempo para preparar as negociações e falou de sua esperança que estas serão efetuadas com espírito construtivo e positivo".
# {'A': None, 'explicou': None, 'é': None, 'preciso': None, 'um': None, 'tempo': None, 'para': None, 'preparar': None, 'as': None, 'negociações': None, 'falou': None, 'de': None, 'espebança': ['esperança', 'esperanças', 'esperança', 'esperanças', 'espelunca', 'esperanto', 'esmeralda', 'espadana', 'espadanas', 'espadana', 'espadanas', 'espadanal', 'espartana', 'espartana', 'espelina'], 'serão': None, 'efetuadas': None, 'com': None, 'espírito': None, 'construtivo': None, 'positivo': None}
# [['esperança', 'espebança']]
#
# Não queriam soltar toda aquela água na superfície se ela estivesse em estado líquido mais abaixo, ela congelaria na superfície e a perfuratriz poderia ficar presa.
# {'Não': None, 'queriam': None, 'soltar': None, 'toda': None, 'água': None, 'em': None, 'a': None, 'suoerfície': ['superfície', 'superfícies', 'subespécie', 'subespécies', 'supercílio', 'supercílios', 'sacerdócio', 'sacerdócios', 'sacrifício', 'sacrifícios'], 'ela': None, 'estivesse': None, 'estado': None, 'líquido': None, 'mais': None, 'abaixo': None, 'congelaria': None, 'superfície': None, 'perfuratriz': None, 'poderia': None, 'ficar': None, 'presa': None}
# [['superfície', 'suoerfície']]
#
# A empresa diz ainda que "segue todos os protocolos e normas de segurança, utilizando-se das mais modernas técnicas e equipamentos de construção", e que venceu licitação cujo processo "foi supervisionado pelos órgãos de fiscalização competentes."
# {'A': None, 'empresa': None, 'diz': None, 'ainda': None, 'segue': None, 'todos': None, 'os': None, 'protocolos': None, 'normas': None, 'de': None, 'segurança': None, 'utilizando': None, 'as': None, 'mais': None, 'modernas': None, 'técnicas': None, 'equipamentos': None, 'construção': None, 'que': None, 'venceu': None, 'licitaçãR': ['licitação', 'licitações', 'licitador', 'licitadora', 'licitadoras', 'licitadores', 'licitante', 'licitantes'], 'processo': None, 'foi': None, 'supervisionado': None, 'por': None, 'órgãos': None, 'fiscalização': None, 'competentes': None}
# [['licitação', 'licitaçãR']]
#
# Por não ter penas, a galinha pesa menos que as outras e fica em desvantagem.
# {'Por': None, 'não': None, 'ter': None, 'Venas': ['vedas', 'veda', 'vedas', 'veda', 'veias', 'veias', 'vejas', 'velas', 'velas', 'vetas', 'vexas', 'vezas'], 'a': None, 'galinha': None, 'pesa': None, 'menos': None, 'as': None, 'outras': None, 'fica': None, 'em': None, 'desvantagem': None}
# [['penas', 'Venas']]

# %%
print("Score:", points / total)
print("Total:", total)
print("Points:", points)
# Out:
# Score: 0.42105263157894735
# Total: 133
# Points: 56
